# %%
import fastf1 as ff1
import pandas as pd
from fastf1 import utils
from matplotlib import pyplot as plt
from fastf1 import plotting
from matplotlib.patches import Rectangle
import numpy as np
import matplotlib as mpl
from matplotlib.collections import LineCollection

ff1.Cache.enable_cache('2023Australia') 
race = ff1.get_session(2023, 'Astralia', 'R')
race_laps = race.load_laps(with_telemetry=True)
race.load()

# %%
driver = "VER"
#driver2 = "HAM"

lapDriver = race_laps.pick_driver(driver).pick_fastest()
#lapDriver2 = race_laps.pick_driver(driver2).pick_fastest()

x = lapDriver.telemetry['X']
#x2 = lapDriver2.telemetry['X']

y = lapDriver.telemetry['Y']
#y2 = lapDriver2.telemetry['X']

color = lapDriver.telemetry['Speed'] 
#color = lapDriver2.telemetry['Speed'] 

points = np.array([x, y]).T.reshape(-1,1,2)
#points2 = np.array([x2, y2]).T.reshape(-1,1,2)

segments = np.concatenate([points[:-1], points[1:]], axis=1)
#segments2 = np.concatenate([points2[:-1], points2[1:]], axis=1)
colormap = mpl.cm.plasma

# %%
ff1.plotting.setup_mpl()

fig, ax = plt.subplots(sharex=True, sharey=True, figsize=(12, 6.75))
fig.suptitle(f'{race.event.name} {race.event.year} - {driver} - Speed', size=24, y=0.97)

plt.subplots_adjust(left=0.1, right=0.9, top=0.9, bottom=0.12)
ax.axis('off')

ax.plot(lapDriver.telemetry['X'], lapDriver.telemetry['Y'], color='black', linestyle='-', linewidth=16, zorder=0)

norm = plt.Normalize(color.min(), color.max())
lc = LineCollection(segments, cmap=colormap, norm=norm, linestyle='-', linewidth=5)

lc.set_array(color)

line = ax.add_collection(lc)

cbaxes = fig.add_axes([0.25, 0.05, 0.5, 0.05])
normlegend = mpl.colors.Normalize(vmin=color.min(), vmax=color.max())
legend = mpl.colorbar.ColorbarBase(cbaxes, norm=normlegend, cmap=colormap, orientation="horizontal")

plt.show()

# %%
driver = "HAM"
#driver2 = "HAM"

lapDriver = race_laps.pick_driver(driver).pick_fastest()
#lapDriver2 = race_laps.pick_driver(driver2).pick_fastest()

x = lapDriver.telemetry['X']
#x2 = lapDriver2.telemetry['X']

y = lapDriver.telemetry['Y']
#y2 = lapDriver2.telemetry['X']

color = lapDriver.telemetry['Speed'] 
#color = lapDriver2.telemetry['Speed'] 

points = np.array([x, y]).T.reshape(-1,1,2)
#points2 = np.array([x2, y2]).T.reshape(-1,1,2)

segments = np.concatenate([points[:-1], points[1:]], axis=1)
#segments2 = np.concatenate([points2[:-1], points2[1:]], axis=1)
colormap = mpl.cm.plasma

ff1.plotting.setup_mpl()

fig, ax = plt.subplots(sharex=True, sharey=True, figsize=(12, 6.75))
fig.suptitle(f'{race.event.name} {race.event.year} - {driver} - Speed', size=24, y=0.97)

plt.subplots_adjust(left=0.1, right=0.9, top=0.9, bottom=0.12)
ax.axis('off')

ax.plot(lapDriver.telemetry['X'], lapDriver.telemetry['Y'], color='black', linestyle='-', linewidth=16, zorder=0)

norm = plt.Normalize(color.min(), color.max())
lc = LineCollection(segments, cmap=colormap, norm=norm, linestyle='-', linewidth=5)

lc.set_array(color)

line = ax.add_collection(lc)

cbaxes = fig.add_axes([0.25, 0.05, 0.5, 0.05])
normlegend = mpl.colors.Normalize(vmin=color.min(), vmax=color.max())
legend = mpl.colorbar.ColorbarBase(cbaxes, norm=normlegend, cmap=colormap, orientation="horizontal")

plt.show()
# Out:
# c:\Users\ricca\OneDrive\Desktop\F1dataAnalysis\env\Lib\site-packages\fastf1\events.py:676: FutureWarning: The `Weekend.name` property is deprecated and will beremoved in a future version.
# Use `Event['EventName']` or `Event.EventName` instead.
#   warnings.warn(
